# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
#Load dataset
df = pd.read_csv('jm_train.csv')

# %%
df.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  target
# 0  0.474335  0.881640 -2.050543 -1.251935 -1.035151 -1.934367       4
# 1 -1.034675  1.741801 -1.660629 -1.555989 -0.337553 -2.473838       0
# 2 -0.563221 -0.688381 -0.318415 -1.845172  0.352366 -0.912928       1
# 3 -1.268179  2.770688  1.054193  2.830389  0.395093  0.677715       3
# 4 -1.216380 -0.391267 -2.898931 -0.913074 -2.171857 -2.367490       0

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'feature1'}>,
#         <AxesSubplot:title={'center':'feature2'}>,
#         <AxesSubplot:title={'center':'feature3'}>],
#        [<AxesSubplot:title={'center':'feature4'}>,
#         <AxesSubplot:title={'center':'feature5'}>,
#         <AxesSubplot:title={'center':'feature6'}>],
#        [<AxesSubplot:title={'center':'target'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df['target'].value_counts()
# Out:
# 0    427
# 3    426
# 1    423
# 2    419
# 4    405
# Name: target, dtype: int64

# %%
df.corr().style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_58305_row0_col0, #T_58305_row1_col1, #T_58305_row2_col2, #T_58305_row3_col3, #T_58305_row4_col4, #T_58305_row5_col5, #T_58305_row6_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_58305_row0_col1 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_58305_row0_col2 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_58305_row0_col3 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_58305_row0_col4 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_58305_row0_col5 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_58305_row0_col6 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_58305_row1_col0, #T_58305_row1_col5, #T_58305_row3_col2, #T_58305_row3_col4, #T_58305_row3_col6, #T_58305_row4_col3, #T_58305_row5_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_58305_row1_col2, #T_58305_row6_col1 {
#   background-color: #f99153;
#   color: #000000;
# }
# ...

# %%
fig, ax = plt.subplots()
for target, color in enumerate(['black','red', 'green', 'blue','yellow']):
    da = df[df['target'] == target]
    plt.scatter(da['feature1'], da['feature4'], c=color, s=da['feature6']*10, label=color)
ax.grid(True)
plt.show()
plt.close()

# %%
X=df[['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6']]  # Features
y=df['target']  # Labels

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7888888888888889

# %%
import random
for _ in range(10):
    a = list(df.loc[random.randint(0,df.shape[0])])
    print(clf.predict([a[:-1]]), a[-1])
# Out:
# [0] 0.0
# [0] 0.0
# [3] 3.0
# [1] 1.0
# [0] 0.0
# [1] 1.0
# [3] 1.0
# [1] 1.0
# [1] 1.0
# [4] 4.0
# c:\Users\alex\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\alex\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\alex\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\alex\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
dtest = pd.read_csv('jm_X_test.csv')

# %%
dtest
# Out:
#      feature1  feature2  feature3  feature4  feature5  feature6
# 0    0.943723 -2.985473 -0.938218  3.580261 -3.038106  2.080338
# 1   -0.899819  1.295568  1.274513  0.718186  1.117035  0.463068
# 2    0.293281 -0.099317  1.874902 -0.589582  1.828441  1.011596
# 3   -1.134804  0.888585 -1.464499 -1.183056 -0.525729 -1.963822
# 4   -0.909240  1.575797  0.697212  1.197092  0.486185  0.222644
# ..        ...       ...       ...       ...       ...       ...
# 895  0.196663 -0.866822 -1.132836 -0.700726 -0.886717 -0.680351
# 896  1.306644  0.543675  0.555275 -0.518374  0.796236  0.297632
# 897 -1.009089  0.359536 -2.253087  0.125687 -1.881437 -1.704497
# 898 -0.339431 -0.560891 -0.256911 -1.576351  0.317480 -0.742085
# 899  1.610331  0.260853 -0.691291 -1.572666  0.096514 -0.750690
#
# [900 rows x 6 columns]

# %%
import random
for _ in range(10):
    a = list(dtest.loc[random.randint(0,dtest.shape[0])])
    print(clf.predict([a]))
# Out:
# [3]
# [3]
# [3]
# [2]
# [4]
# [3]
# [3]
# [4]
# [3]
# [1]
# c:\Users\alex\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\alex\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\alex\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\alex\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...
